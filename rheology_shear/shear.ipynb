# %%
import shear
shear.main(save_blob_data=True)
# Out:
#  20%|██        | 1/5 [00:00<00:01,  2.54it/s]
# N=12 stress: [0.11304633 0.25687004 0.45067041 0.64947685 0.96895178 1.20652167
#  1.52839295 1.94610008 2.42089889 2.84776675]
#  40%|████      | 2/5 [00:01<00:01,  1.68it/s]
# N=42 stress: [0.12164282 0.28058634 0.51858894 0.75384818 1.18257466 1.51163147
#  1.99208329 2.71481108 3.60089293 4.47327876]
#  60%|██████    | 3/5 [00:03<00:03,  1.59s/it]
# N=162 stress: [0.11983123 0.27772915 0.5159947  0.75953232 1.21107235 1.57384929
#  2.09909152 2.95218039 4.13338687 5.34604452]
#  80%|████████  | 4/5 [00:16<00:05,  5.94s/it]
# N=642 stress: [0.11888346 0.27574264 0.51223069 0.75614691 1.21087674 1.5873934
#  2.11103252 2.99797752 4.32503928 5.7165725 ]
# 100%|██████████| 5/5 [01:18<00:00, 15.76s/it]
# N=2562 stress: [0.11874736 0.27605127 0.5116706  0.75485    1.21209328 1.5963489
#  2.11648438 3.0225497  4.4239569  5.92621912]

# %%
import plotting.rigid_spheres as plt
plt.main()
# Out:
# 	[0]: NVIDIA GeForce RTX 3080 Laptop GPU
# 	Selected devices: [0]
# 	Primary device: 0

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('rigid_spheres.png')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import plotting.optix as optix
optix.main("optix_scene.png")
# Out:
# /home/raul/miniforge3/envs/libmobility-examples/lib/python3.12/site-packages/numpy/_core/getlimits.py:552: UserWarning: Signature b'\x00\xd0\xcc\xcc\xcc\xcc\xcc\xcc\xfb\xbf\x00\x00\x00\x00\x00\x00' for <class 'numpy.longdouble'> does not match any known type: falling back to type probe function.
# This warnings indicates broken support for the dtype!
#   machar = _get_machar(dtype)
# 	[0]: NVIDIA GeForce RTX 3080 Laptop GPU
# 	Selected devices: [0]
# 	Primary device: 0

# %%
# render the image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('optix_scene.png')
plt.imshow(img)
plt.axis('off')
plt.show()
