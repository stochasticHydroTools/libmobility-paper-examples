# %%
import rollers
rollers.main(mass_facts=[0.1, 1.0], n_runs=4)
# Out:
# mass factor:   0%|          | 0/2 [00:00<?, ?it/s]
# 2025-10-07 19:09:54,823 - INFO - output dir: hg61/deterministic/0/
# 2025-10-07 19:09:54,823 - INFO - grav height h_g: 3.9548995641599847
# 2025-10-07 19:09:55,173 - INFO - n steps: 13
# 2025-10-07 19:09:55,173 - INFO - saving every 6
# 2025-10-07 19:09:55,174 - INFO - Saved parameters to hg61/deterministic/0/params.json
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# simulation: 100%|██████████| 13/13 [00:01<00:00,  7.99it/s]
#
# 2025-10-07 19:09:58,935 - INFO - output dir: hg61/deterministic/1/
# 2025-10-07 19:09:58,936 - INFO - grav height h_g: 3.9548995641599847
# 2025-10-07 19:09:59,259 - INFO - n steps: 13
# 2025-10-07 19:09:59,260 - INFO - saving every 6
# 2025-10-07 19:09:59,260 - INFO - Saved parameters to hg61/deterministic/1/params.json
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# simulation: 100%|██████████| 13/13 [00:01<00:00,  7.95it/s]
#
# ...

# %%
import process_data as pd
pd.main()

# %%
import plotting.optix as optix
optix.main(hg=15, t_star="t_star")
# Out:
# /home/rfish/local/miniconda3/envs/libmobility-examples/lib/python3.12/site-packages/numpy/_core/getlimits.py:552: UserWarning: Signature b'\x00\xd0\xcc\xcc\xcc\xcc\xcc\xcc\xfb\xbf\x00\x00\x00\x00\x00\x00' for <class 'numpy.longdouble'> does not match any known type: falling back to type probe function.
# This warnings indicates broken support for the dtype!
#   machar = _get_machar(dtype)
# **********************************************************************************
# **********************************************************************************
# Video encoding library initialization failed, encoding features are not available.
# libavcodec.so.61: cannot open shared object file: No such file or directory
# **********************************************************************************
# **********************************************************************************
# 	[0]: NVIDIA GeForce RTX 4070
# 	Selected devices: [0]
# 	Primary device: 0
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('./plotting/plots/roller_hg15_t_star.png')
plt.imshow(img)
plt.axis('off')
plt.show()

img = mpimg.imread('./plotting/plots/roller_hg15_2t_star.png')
plt.imshow(img)
plt.axis('off')
plt.show()
